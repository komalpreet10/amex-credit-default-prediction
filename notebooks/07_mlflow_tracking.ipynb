# %% [markdown]
# # 07 MLflow Tracking
#
# Log LightGBM, XGBoost, model-comparison, plot, prediction, and final-model artifacts to a local MLflow experiment. Run this after notebooks 03-06.

# %%
import os
os.environ["MLFLOW_ALLOW_FILE_STORE"] = "true"

# %%
from pathlib import Path
import sys

import pandas as pd
from IPython.display import display

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

from amex_default.tracking import configure_mlflow, log_project_artifacts

configure_mlflow(PROJECT_ROOT, "amex-default-prediction")
# Out:
# 2026/06/22 11:04:48 INFO mlflow.tracking.fluent: Experiment with name 'amex-default-prediction' does not exist. Creating a new experiment.

# %%
logged_metrics = log_project_artifacts()

if logged_metrics:
    display(pd.DataFrame(logged_metrics)[[
        "model", "n_rows", "n_features", "roc_auc", "pr_auc",
        "precision", "recall", "f1", "training_time_seconds",
        "inference_time_seconds", "total_time_seconds",
    ]])
else:
    print("No model metrics found. Run notebooks 03 and 04 before MLflow tracking.")
# Out:
#       model  n_rows  n_features   roc_auc    pr_auc  precision    recall  \
# 0  lightgbm  229456        3418  0.959328  0.893820   0.810382  0.805854
# 1   xgboost  229456        3418  0.959721  0.894806   0.812402  0.803514
#
#          f1  training_time_seconds  inference_time_seconds  total_time_seconds
# 0  0.808112             901.473069                1.775503          903.248572
# 1  0.807934            4996.370889                0.418710         4996.789599

# %% [markdown]
# Start the local MLflow UI from the project root with:
#
# ```bash
# mlflow ui --backend-store-uri ./mlruns
# ```
